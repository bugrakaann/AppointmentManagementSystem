# %% [markdown]
# <a href="https://colab.research.google.com/github/bugrakaann/AppointmentManagementSystem/blob/main/TrainAutoencoderDefectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# Kaggle kimlik bilgilerini ortam değişkenlerine ayarla
os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

print("Kaggle kimlik bilgileri başarıyla ayarlandı.")
# Out:
# Kaggle kimlik bilgileri başarıyla ayarlandı.

# %%
# Veri setini indir
# !kaggle datasets download -d ipythonx/mvtec-ad

# İndirilen zip dosyasını aç
# !unzip mvtec-ad.zip -d /content/mvtec-ad

print("Veri seti başarıyla indirildi ve açıldı.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ipythonx/mvtec-ad
# License(s): copyright-authors
# User cancelled operation
# Archive:  mvtec-ad.zip
# replace /content/mvtec-ad/bottle/ground_truth/broken_large/000_mask.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: Veri seti başarıyla indirildi ve açıldı.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
import os
from pathlib import Path
import matplotlib.pyplot as plt

def ssim_loss(y_true, y_pred):
    return 1 - tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
def load_images(data_path, img_size=(256, 256)):
    images = []
    for img_file in Path(data_path).glob('**/*.png'):
        img = cv2.imread(str(img_file))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        img = img.astype('float32') / 255.0
        images.append(img)
    return np.array(images)

#Büyük işlemlerde DataLoader kullanmak ram için daha verimli
category = 'leather'  # kategori
train_path = f'/content/mvtec-ad/{category}/train/good'

train_images = load_images(train_path)

# %%
def build_autoencoder(input_shape=(256, 256, 3)):
    # Encoder
    encoder_input = keras.Input(shape=input_shape)

    x = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoder_input)
    x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x)

    # Decoder
    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(encoded)
    x = keras.layers.UpSampling2D((2, 2))(x)

    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.UpSampling2D((2, 2))(x)

    x = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.UpSampling2D((2, 2))(x)

    decoded = keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

    autoencoder = keras.Model(encoder_input, decoded)
    return autoencoder

model = build_autoencoder()
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_12 (UpSampling2D) │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_13 (UpSampling2D) │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_14 (UpSampling2D) │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,955 (1.27 MB)
#  Trainable params: 333,955 (1.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Model derleme
model.compile(
    optimizer='adam',
    loss=ssim_loss,  # SSIM loss kullanıldı
    metrics=['mae']
)

# Eğitim
history = model.fit(
    train_images, train_images,  # Input ve output aynı
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    shuffle=True,
    callbacks=[
        keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
    ]
)

# Modeli kaydetme
model.save('autoencoder_model.h5')
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 907ms/step - loss: 0.5384 - mae: 0.1647 - val_loss: 0.4802 - val_mae: 0.0734 - learning_rate: 0.0010
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4794 - mae: 0.0644 - val_loss: 0.4687 - val_mae: 0.0499 - learning_rate: 0.0010
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4713 - mae: 0.0482 - val_loss: 0.4659 - val_mae: 0.0435 - learning_rate: 0.0010
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.4688 - mae: 0.0446 - val_loss: 0.4646 - val_mae: 0.0433 - learning_rate: 0.0010
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4646 - mae: 0.0442 - val_loss: 0.4636 - val_mae: 0.0400 - learning_rate: 0.0010
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.4647 - mae: 0.0417 - val_loss: 0.4622 - val_mae: 0.0386 - learning_rate: 0.0010
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.4623 - mae: 0.0406 - val_loss: 0.4619 - val_mae: 0.0384 - learning_rate: 0.0010
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4632 - mae: 0.0397 - val_loss: 0.4617 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.4644 - mae: 0.0389 - val_loss: 0.4622 - val_mae: 0.0396 - learning_rate: 0.0010
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.4646 - mae: 0.0396 - val_loss: 0.4599 - val_mae: 0.0340 - learning_rate: 0.0010
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4586 - mae: 0.0363 - val_loss: 0.4619 - val_mae: 0.0394 - learning_rate: 0.0010
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4669 - mae: 0.0397 - val_loss: 0.4605 - val_mae: 0.0362 - learning_rate: 0.0010
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4629 - mae: 0.0361 - val_loss: 0.4613 - val_mae: 0.0369 - learning_rate: 0.0010
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4615 - mae: 0.0365 - val_loss: 0.4587 - val_mae: 0.0324 - learning_rate: 0.0010
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.4589 - mae: 0.0326 - val_loss: 0.4576 - val_mae: 0.0295 - learning_rate: 0.0010
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4600 - mae: 0.0304 - val_loss: 0.4601 - val_mae: 0.0355 - learning_rate: 0.0010
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4606 - mae: 0.0349 - val_loss: 0.4599 - val_mae: 0.0356 - learning_rate: 0.0010
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4615 - mae: 0.0333 - val_loss: 0.4567 - val_mae: 0.0293 - learning_rate: 0.0010
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.4586 - mae: 0.0297 - val_loss: 0.4558 - val_mae: 0.0273 - learning_rate: 0.0010
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4555 - mae: 0.0290 - val_loss: 0.4556 - val_mae: 0.0276 - learning_rate: 0.0010
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4537 - mae: 0.0278 - val_loss: 0.4551 - val_mae: 0.0282 - learning_rate: 0.0010
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4592 - mae: 0.0279 - val_loss: 0.4546 - val_mae: 0.0288 - learning_rate: 0.0010
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.4549 - mae: 0.0280 - val_loss: 0.4531 - val_mae: 0.0259 - learning_rate: 0.0010
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4496 - mae: 0.0259 - val_loss: 0.4522 - val_mae: 0.0261 - learning_rate: 0.0010
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4499 - mae: 0.0263 - val_loss: 0.4510 - val_mae: 0.0259 - learning_rate: 0.0010
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4489 - mae: 0.0257 - val_loss: 0.4499 - val_mae: 0.0277 - learning_rate: 0.0010
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4496 - mae: 0.0270 - val_loss: 0.4479 - val_mae: 0.0253 - learning_rate: 0.0010
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4506 - mae: 0.0261 - val_loss: 0.4460 - val_mae: 0.0262 - learning_rate: 0.0010
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4449 - mae: 0.0267 - val_loss: 0.4437 - val_mae: 0.0255 - learning_rate: 0.0010
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.4467 - mae: 0.0258 - val_loss: 0.4407 - val_mae: 0.0250 - learning_rate: 0.0010
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4429 - mae: 0.0256 - val_loss: 0.4377 - val_mae: 0.0269 - learning_rate: 0.0010
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4347 - mae: 0.0260 - val_loss: 0.4317 - val_mae: 0.0253 - learning_rate: 0.0010
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.4310 - mae: 0.0271 - val_loss: 0.4250 - val_mae: 0.0249 - learning_rate: 0.0010
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4198 - mae: 0.0252 - val_loss: 0.4310 - val_mae: 0.0646 - learning_rate: 0.0010
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4279 - mae: 0.0530 - val_loss: 0.4143 - val_mae: 0.0295 - learning_rate: 0.0010
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4182 - mae: 0.0370 - val_loss: 0.4115 - val_mae: 0.0355 - learning_rate: 0.0010
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.4087 - mae: 0.0337 - val_loss: 0.4084 - val_mae: 0.0357 - learning_rate: 0.0010
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4058 - mae: 0.0331 - val_loss: 0.4014 - val_mae: 0.0305 - learning_rate: 0.0010
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4006 - mae: 0.0288 - val_loss: 0.3967 - val_mae: 0.0250 - learning_rate: 0.0010
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.3969 - mae: 0.0263 - val_loss: 0.3942 - val_mae: 0.0263 - learning_rate: 0.0010
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.3949 - mae: 0.0262 - val_loss: 0.3906 - val_mae: 0.0241 - learning_rate: 0.0010
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.3916 - mae: 0.0250 - val_loss: 0.3878 - val_mae: 0.0240 - learning_rate: 0.0010
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.3850 - mae: 0.0246 - val_loss: 0.3851 - val_mae: 0.0243 - learning_rate: 0.0010
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3859 - mae: 0.0249 - val_loss: 0.3829 - val_mae: 0.0252 - learning_rate: 0.0010
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3834 - mae: 0.0249 - val_loss: 0.3801 - val_mae: 0.0246 - learning_rate: 0.0010
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.3796 - mae: 0.0249 - val_loss: 0.3777 - val_mae: 0.0268 - learning_rate: 0.0010
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3741 - mae: 0.0253 - val_loss: 0.3744 - val_mae: 0.0238 - learning_rate: 0.0010
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3748 - mae: 0.0239 - val_loss: 0.3716 - val_mae: 0.0237 - learning_rate: 0.0010
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3702 - mae: 0.0237 - val_loss: 0.3687 - val_mae: 0.0234 - learning_rate: 0.0010
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.3694 - mae: 0.0236 - val_loss: 0.3657 - val_mae: 0.0234 - learning_rate: 0.0010
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.3652 - mae: 0.0243 - val_loss: 0.3628 - val_mae: 0.0235 - learning_rate: 0.0010
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3638 - mae: 0.0238 - val_loss: 0.3612 - val_mae: 0.0275 - learning_rate: 0.0010
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3615 - mae: 0.0303 - val_loss: 0.3569 - val_mae: 0.0236 - learning_rate: 0.0010
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3589 - mae: 0.0271 - val_loss: 0.3584 - val_mae: 0.0336 - learning_rate: 0.0010
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3586 - mae: 0.0328 - val_loss: 0.3540 - val_mae: 0.0273 - learning_rate: 0.0010
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3547 - mae: 0.0271 - val_loss: 0.3504 - val_mae: 0.0248 - learning_rate: 0.0010
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3499 - mae: 0.0242 - val_loss: 0.3477 - val_mae: 0.0232 - learning_rate: 0.0010
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3469 - mae: 0.0244 - val_loss: 0.3456 - val_mae: 0.0230 - learning_rate: 0.0010
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3455 - mae: 0.0239 - val_loss: 0.3438 - val_mae: 0.0243 - learning_rate: 0.0010
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.3438 - mae: 0.0238 - val_loss: 0.3418 - val_mae: 0.0241 - learning_rate: 0.0010
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.3422 - mae: 0.0240 - val_loss: 0.3397 - val_mae: 0.0235 - learning_rate: 0.0010
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3389 - mae: 0.0232 - val_loss: 0.3375 - val_mae: 0.0228 - learning_rate: 0.0010
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3363 - mae: 0.0229 - val_loss: 0.3359 - val_mae: 0.0228 - learning_rate: 0.0010
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.3348 - mae: 0.0229 - val_loss: 0.3342 - val_mae: 0.0230 - learning_rate: 0.0010
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3329 - mae: 0.0229 - val_loss: 0.3325 - val_mae: 0.0227 - learning_rate: 0.0010
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3342 - mae: 0.0254 - val_loss: 0.3314 - val_mae: 0.0236 - learning_rate: 0.0010
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3289 - mae: 0.0253 - val_loss: 0.3302 - val_mae: 0.0238 - learning_rate: 0.0010
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.3296 - mae: 0.0238 - val_loss: 0.3286 - val_mae: 0.0233 - learning_rate: 0.0010
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 0.3289 - mae: 0.0233 - val_loss: 0.3273 - val_mae: 0.0230 - learning_rate: 0.0010
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.3267 - mae: 0.0229 - val_loss: 0.3259 - val_mae: 0.0227 - learning_rate: 0.0010
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.3246 - mae: 0.0227 - val_loss: 0.3246 - val_mae: 0.0234 - learning_rate: 0.0010
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3244 - mae: 0.0231 - val_loss: 0.3231 - val_mae: 0.0225 - learning_rate: 0.0010
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3224 - mae: 0.0226 - val_loss: 0.3223 - val_mae: 0.0232 - learning_rate: 0.0010
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3206 - mae: 0.0272 - val_loss: 0.3230 - val_mae: 0.0261 - learning_rate: 0.0010
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.3222 - mae: 0.0275 - val_loss: 0.3215 - val_mae: 0.0242 - learning_rate: 0.0010
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.3196 - mae: 0.0241 - val_loss: 0.3197 - val_mae: 0.0227 - learning_rate: 0.0010
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3214 - mae: 0.0236 - val_loss: 0.3191 - val_mae: 0.0235 - learning_rate: 0.0010
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.3199 - mae: 0.0233 - val_loss: 0.3176 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.3164 - mae: 0.0226 - val_loss: 0.3165 - val_mae: 0.0225 - learning_rate: 0.0010
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - loss: 0.3158 - mae: 0.0225 - val_loss: 0.3158 - val_mae: 0.0236 - learning_rate: 0.0010
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3117 - mae: 0.0230 - val_loss: 0.3147 - val_mae: 0.0226 - learning_rate: 0.0010
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3113 - mae: 0.0235 - val_loss: 0.3146 - val_mae: 0.0254 - learning_rate: 0.0010
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3127 - mae: 0.0246 - val_loss: 0.3139 - val_mae: 0.0234 - learning_rate: 0.0010
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3126 - mae: 0.0238 - val_loss: 0.3127 - val_mae: 0.0222 - learning_rate: 0.0010
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3108 - mae: 0.0227 - val_loss: 0.3119 - val_mae: 0.0221 - learning_rate: 0.0010
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3125 - mae: 0.0239 - val_loss: 0.3111 - val_mae: 0.0221 - learning_rate: 0.0010
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.3087 - mae: 0.0236 - val_loss: 0.3119 - val_mae: 0.0266 - learning_rate: 0.0010
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.3115 - mae: 0.0252 - val_loss: 0.3103 - val_mae: 0.0241 - learning_rate: 0.0010
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3093 - mae: 0.0235 - val_loss: 0.3092 - val_mae: 0.0227 - learning_rate: 0.0010
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3079 - mae: 0.0227 - val_loss: 0.3084 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3079 - mae: 0.0223 - val_loss: 0.3076 - val_mae: 0.0220 - learning_rate: 0.0010
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.3034 - mae: 0.0219 - val_loss: 0.3070 - val_mae: 0.0224 - learning_rate: 0.0010
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3049 - mae: 0.0223 - val_loss: 0.3065 - val_mae: 0.0221 - learning_rate: 0.0010
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.3040 - mae: 0.0221 - val_loss: 0.3056 - val_mae: 0.0220 - learning_rate: 0.0010
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.3035 - mae: 0.0220 - val_loss: 0.3052 - val_mae: 0.0228 - learning_rate: 0.0010
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3057 - mae: 0.0265 - val_loss: 0.3064 - val_mae: 0.0280 - learning_rate: 0.0010
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 0.3033 - mae: 0.0255 - val_loss: 0.3039 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - loss: 0.3028 - mae: 0.0228 - val_loss: 0.3034 - val_mae: 0.0229 - learning_rate: 0.0010
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.3024 - mae: 0.0237 - val_loss: 0.3028 - val_mae: 0.0219 - learning_rate: 0.0010
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.3025 - mae: 0.0226 - val_loss: 0.3016 - val_mae: 0.0220 - learning_rate: 0.0010
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def detect_anomalies(model, test_images, threshold=None):
    # Rekonstrüksiyon
    reconstructed = model.predict(test_images)

    # Rekonstrüksiyon hatası
    mse = np.mean(np.square(test_images - reconstructed), axis=(1, 2, 3))

    # Threshold belirleme (eğer verilmemişse)
    if threshold is None:
        threshold = np.mean(mse) + 2 * np.std(mse)

    # Anomali tespiti
    anomalies = mse > threshold

    return mse, anomalies, reconstructed

# Test veri yükleme
test_path = f'/content/mvtec-ad/{category}/test'
test_images = load_images(test_path)

# Anomali tespiti
mse_scores, is_anomaly, reconstructed = detect_anomalies(model, test_images)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step

# %%
def visualize_results(original, reconstructed, mse, n_samples=5):
    plt.figure(figsize=(15, 6))

    for i in range(n_samples):
        # Orijinal görüntü
        plt.subplot(3, n_samples, i + 1)
        plt.imshow(original[i])
        plt.title(f'Original')
        plt.axis('off')

        # Rekonstrüksiyon
        plt.subplot(3, n_samples, n_samples + i + 1)
        plt.imshow(reconstructed[i])
        plt.title(f'Reconstructed')
        plt.axis('off')

        # Fark haritası
        plt.subplot(3, n_samples, 2*n_samples + i + 1)
        diff = np.abs(original[i] - reconstructed[i])
        plt.imshow(diff)
        plt.title(f'MSE: {mse[i]:.4f}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

visualize_results(test_images, reconstructed, mse_scores)

# %%
def evaluate_model(model, category=category):
    # Normal örnekler
    normal_path = f'/content/mvtec-ad/{category}/test/good'
    normal_images = load_images(normal_path)
    normal_recon = model.predict(normal_images)
    normal_mse = np.mean(np.square(normal_images - normal_recon), axis=(1,2,3))

    # Anomalili örnekler (tüm defekt tipleri)
    anomaly_mse = []
    defect_types = []

    test_path = Path(f'/content/mvtec-ad/{category}/test')
    for defect_dir in test_path.iterdir():
        if defect_dir.name != 'good' and defect_dir.is_dir():
            anomaly_images = load_images(str(defect_dir))
            anomaly_recon = model.predict(anomaly_images)
            mse = np.mean(np.square(anomaly_images - anomaly_recon), axis=(1,2,3))
            anomaly_mse.extend(mse)
            defect_types.extend([defect_dir.name] * len(mse))

    anomaly_mse = np.array(anomaly_mse)

    # Görselleştirme
    plt.figure(figsize=(12, 6))
    plt.hist(normal_mse, bins=30, alpha=0.7, label='Normal', color='green')
    plt.hist(anomaly_mse, bins=30, alpha=0.7, label='Anomaly', color='red')
    plt.xlabel('MSE')
    plt.ylabel('Frequency')
    plt.legend()
    plt.title('MSE Distribution: Normal vs Anomaly')
    plt.show()

    # İstatistikler
    print(f"Normal MSE: {normal_mse.mean():.6f} ± {normal_mse.std():.6f}")
    print(f"Anomaly MSE: {anomaly_mse.mean():.6f} ± {anomaly_mse.std():.6f}")
    print(f"Separation ratio: {anomaly_mse.mean() / normal_mse.mean():.2f}x")

    return normal_mse, anomaly_mse

normal_scores, anomaly_scores = evaluate_model(model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Normal MSE: 0.001763 ± 0.000239
# Anomaly MSE: 0.001578 ± 0.000336
# Separation ratio: 0.89x

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import cv2
import os
from pathlib import Path
import matplotlib.pyplot as plt

def ssim_loss(y_true, y_pred):
    return 1 - tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
def load_images(data_path, img_size=(256, 256)):
    images = []
    path_obj = Path(data_path)
    if not path_obj.exists():
        print(f"Uyarı: {data_path} yolu bulunamadı!")
        return np.array([])

    for img_file in path_obj.glob('**/*.png'):
        img = cv2.imread(str(img_file))
        if img is None: continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        img = img.astype('float32') / 255.0
        images.append(img)
    return np.array(images)

# NOISE INJECTION FUNCTION
def add_noise(images, noise_factor=0.1):
    noisy_images = images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=images.shape)
    noisy_images = np.clip(noisy_images, 0., 1.)
    return noisy_images

category = 'leather'  # kategori
base_path = '/content/mvtec-ad' if os.path.exists('/content/mvtec-ad') else '.'
train_path = f'{base_path}/{category}/train/good'

train_images_clean = load_images(train_path)
# Add noise to create training inputs
train_images_noisy = add_noise(train_images_clean, noise_factor=0.2)

print(f"Eğitim için {len(train_images_clean)} görüntü yüklendi.")

# Show example of noise
if len(train_images_clean) > 0:
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1); plt.imshow(train_images_clean[0]); plt.title('Clean')
    plt.subplot(1, 2, 2); plt.imshow(train_images_noisy[0]); plt.title('Noisy (Input)')
    plt.show()
# Out:
# Eğitim için 245 görüntü yüklendi.

# %%
def build_autoencoder_simple(input_shape=(256, 256, 3)):
    # Standard Autoencoder (Simpler than before to prevent Identity Mapping)
    encoder_input = keras.Input(shape=input_shape)

    x = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoder_input)
    x = keras.layers.MaxPooling2D((2, 2), padding='same')(x) # 128

    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.MaxPooling2D((2, 2), padding='same')(x) # 64

    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    encoded = keras.layers.MaxPooling2D((2, 2), padding='same')(x) # 32x32 BOttleneck
    # Note: We kept it slightly larger (32x32) because Denoising is the main regularizer now.
    # If it still copies, we will reduce to 16x16.

    x = keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(encoded)
    x = keras.layers.UpSampling2D((2, 2))(x)

    x = keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.UpSampling2D((2, 2))(x)

    x = keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = keras.layers.UpSampling2D((2, 2))(x)

    decoded = keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

    autoencoder = keras.Model(encoder_input, decoded)
    return autoencoder

model = build_autoencoder_simple()
model.compile(optimizer='adam', loss=ssim_loss)
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_15 (UpSampling2D) │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_16 (UpSampling2D) │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_17 (UpSampling2D) │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 333,955 (1.27 MB)
#  Trainable params: 333,955 (1.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Eğitim
if len(train_images_clean) > 0:
    history = model.fit(
        train_images_noisy, train_images_clean,  # Input: Noisy, Target: Clean
        epochs=100,
        batch_size=32,
        validation_split=0.2,
        shuffle=True,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
            keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
        ]
    )
    model.save('denoising_autoencoder.keras')
else:
    print("Eğitilecek veri bulunamadı.")
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 748ms/step - loss: 0.5278 - val_loss: 0.4692 - learning_rate: 0.0010
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4710 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4614 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4657 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4624 - val_loss: 0.4595 - learning_rate: 0.0010
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.4640 - val_loss: 0.4589 - learning_rate: 0.0010
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.4574 - val_loss: 0.4588 - learning_rate: 0.0010
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4596 - val_loss: 0.4583 - learning_rate: 0.0010
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4600 - val_loss: 0.4581 - learning_rate: 0.0010
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4604 - val_loss: 0.4579 - learning_rate: 0.0010
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4579 - val_loss: 0.4602 - learning_rate: 0.0010
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.4607 - val_loss: 0.4598 - learning_rate: 0.0010
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4625 - val_loss: 0.4577 - learning_rate: 0.0010
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.4611 - val_loss: 0.4595 - learning_rate: 0.0010
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4618 - val_loss: 0.4576 - learning_rate: 0.0010
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 0.4593 - val_loss: 0.4580 - learning_rate: 0.0010
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.4560 - val_loss: 0.4577 - learning_rate: 0.0010
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4553 - val_loss: 0.4575 - learning_rate: 0.0010
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.4599 - val_loss: 0.4573 - learning_rate: 0.0010
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4550 - val_loss: 0.4572 - learning_rate: 0.0010
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4574 - val_loss: 0.4573 - learning_rate: 0.0010
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4556 - val_loss: 0.4571 - learning_rate: 0.0010
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4593 - val_loss: 0.4570 - learning_rate: 0.0010
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4581 - val_loss: 0.4571 - learning_rate: 0.0010
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.4574 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4548 - val_loss: 0.4564 - learning_rate: 0.0010
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4618 - val_loss: 0.4560 - learning_rate: 0.0010
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4592 - val_loss: 0.4553 - learning_rate: 0.0010
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4577 - val_loss: 0.4544 - learning_rate: 0.0010
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4538 - val_loss: 0.4530 - learning_rate: 0.0010
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4513 - val_loss: 0.4519 - learning_rate: 0.0010
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4508 - val_loss: 0.4529 - learning_rate: 0.0010
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4542 - val_loss: 0.4495 - learning_rate: 0.0010
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4486 - val_loss: 0.4491 - learning_rate: 0.0010
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 0.4467 - val_loss: 0.4486 - learning_rate: 0.0010
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.4467 - val_loss: 0.4468 - learning_rate: 0.0010
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4491 - val_loss: 0.4466 - learning_rate: 0.0010
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4488 - val_loss: 0.4468 - learning_rate: 0.0010
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4452 - val_loss: 0.4474 - learning_rate: 0.0010
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4464 - val_loss: 0.4451 - learning_rate: 0.0010
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4429 - val_loss: 0.4442 - learning_rate: 0.0010
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4443 - val_loss: 0.4443 - learning_rate: 0.0010
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4427 - val_loss: 0.4441 - learning_rate: 0.0010
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.4427 - val_loss: 0.4430 - learning_rate: 0.0010
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.4419 - val_loss: 0.4423 - learning_rate: 0.0010
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4405 - val_loss: 0.4423 - learning_rate: 0.0010
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4408 - val_loss: 0.4419 - learning_rate: 0.0010
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4433 - val_loss: 0.4418 - learning_rate: 0.0010
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.4387 - val_loss: 0.4411 - learning_rate: 0.0010
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4354 - val_loss: 0.4410 - learning_rate: 0.0010
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4376 - val_loss: 0.4409 - learning_rate: 0.0010
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4400 - val_loss: 0.4414 - learning_rate: 0.0010
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.4398 - val_loss: 0.4398 - learning_rate: 0.0010
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4389 - val_loss: 0.4400 - learning_rate: 0.0010
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4364 - val_loss: 0.4394 - learning_rate: 0.0010
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4379 - val_loss: 0.4394 - learning_rate: 0.0010
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4340 - val_loss: 0.4402 - learning_rate: 0.0010
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4345 - val_loss: 0.4399 - learning_rate: 0.0010
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4347 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4349 - val_loss: 0.4383 - learning_rate: 0.0010
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4356 - val_loss: 0.4380 - learning_rate: 0.0010
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.4336 - val_loss: 0.4378 - learning_rate: 0.0010
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - loss: 0.4288 - val_loss: 0.4385 - learning_rate: 0.0010
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4350 - val_loss: 0.4376 - learning_rate: 0.0010
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4328 - val_loss: 0.4374 - learning_rate: 0.0010
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.4354 - val_loss: 0.4370 - learning_rate: 0.0010
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4304 - val_loss: 0.4375 - learning_rate: 0.0010
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4323 - val_loss: 0.4372 - learning_rate: 0.0010
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4324 - val_loss: 0.4375 - learning_rate: 0.0010
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4320 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.4325 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4318 - val_loss: 0.4372 - learning_rate: 0.0010
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4290 - val_loss: 0.4364 - learning_rate: 0.0010
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4295 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4336 - val_loss: 0.4379 - learning_rate: 0.0010
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4296 - val_loss: 0.4365 - learning_rate: 0.0010
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4299 - val_loss: 0.4364 - learning_rate: 0.0010
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4299 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4273 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4313 - val_loss: 0.4364 - learning_rate: 0.0010
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.4299 - val_loss: 0.4360 - learning_rate: 0.0010
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4289 - val_loss: 0.4359 - learning_rate: 0.0010
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4290 - val_loss: 0.4359 - learning_rate: 0.0010
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.4274 - val_loss: 0.4359 - learning_rate: 0.0010
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4268 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4261 - val_loss: 0.4355 - learning_rate: 0.0010
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4260 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4288 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4263 - val_loss: 0.4360 - learning_rate: 0.0010
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4252 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.4235 - val_loss: 0.4353 - learning_rate: 5.0000e-04
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4264 - val_loss: 0.4359 - learning_rate: 5.0000e-04
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4260 - val_loss: 0.4355 - learning_rate: 5.0000e-04
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.4262 - val_loss: 0.4351 - learning_rate: 5.0000e-04
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4249 - val_loss: 0.4362 - learning_rate: 5.0000e-04
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4261 - val_loss: 0.4352 - learning_rate: 5.0000e-04
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.4254 - val_loss: 0.4358 - learning_rate: 5.0000e-04
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.4240 - val_loss: 0.4356 - learning_rate: 5.0000e-04
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.4256 - val_loss: 0.4351 - learning_rate: 5.0000e-04
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4220 - val_loss: 0.4351 - learning_rate: 2.5000e-04

# %%
def detect_anomalies_ssim(model, test_images):
    if len(test_images) == 0: return [], [], []

    # Rekonstrüksiyon
    reconstructed = model.predict(test_images)

    # SSIM MAP Computation
    # tf.image.ssim returns a single score per image. We want a MAP.
    # Unfortunately standard TF doesn't give Map easily. We can use abs diff for viz,
    # but for scoring we use 1 - ssim.

    # 1. SSIM Score (Global)
    ssim_scores = tf.image.ssim(test_images, reconstructed, max_val=1.0).numpy()
    anomaly_score = 1 - ssim_scores  # Higher score = More Anomaly

    # 2. Difference Map (for Visualization)
    diff_map = np.abs(test_images - reconstructed)
    diff_map = np.mean(diff_map, axis=-1) # Grayscale difference

    return anomaly_score, diff_map, reconstructed

# Test veri yükleme
test_path = f'{base_path}/{category}/test'
test_images = load_images(test_path)

if 'model' in locals() and len(test_images) > 0:
    scores, diff_maps, reconstructed = detect_anomalies_ssim(model, test_images)

    # Thresholding based on Scores
    print(f"Mean Score: {np.mean(scores):.4f}, Max Score: {np.max(scores):.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 255ms/step
# Mean Score: 0.5267, Max Score: 0.5829

# %%
def visualize_ssim_results(original, reconstructed, diff_maps, scores, n_samples=5):
    if len(original) == 0: return
    n_samples = min(n_samples, len(original))

    plt.figure(figsize=(15, 6))

    for i in range(n_samples):
        # Orijinal
        plt.subplot(3, n_samples, i + 1)
        plt.imshow(original[i])
        plt.title('Original')
        plt.axis('off')

        # Rekonstrüksiyon
        plt.subplot(3, n_samples, n_samples + i + 1)
        plt.imshow(reconstructed[i])
        plt.title('Reconstructed')
        plt.axis('off')

        # Hata Haritası
        plt.subplot(3, n_samples, 2*n_samples + i + 1)
        plt.imshow(diff_maps[i], cmap='jet', vmin=0, vmax=0.3) # Jet cmap highlights defects
        plt.title(f'Score: {scores[i]:.4f}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

if 'scores' in locals() and len(test_images) > 0:
    visualize_ssim_results(test_images, reconstructed, diff_maps, scores)

# %%
def evaluate_model(model, category=category):
    # Normal örnekler
    normal_path = f'/content/mvtec-ad/{category}/test/good'
    normal_images = load_images(normal_path)
    normal_recon = model.predict(normal_images)
    normal_mse = np.mean(np.square(normal_images - normal_recon), axis=(1,2,3))

    # Anomalili örnekler (tüm defekt tipleri)
    anomaly_mse = []
    defect_types = []

    test_path = Path(f'/content/mvtec-ad/{category}/test')
    for defect_dir in test_path.iterdir():
        if defect_dir.name != 'good' and defect_dir.is_dir():
            anomaly_images = load_images(str(defect_dir))
            anomaly_recon = model.predict(anomaly_images)
            mse = np.mean(np.square(anomaly_images - anomaly_recon), axis=(1,2,3))
            anomaly_mse.extend(mse)
            defect_types.extend([defect_dir.name] * len(mse))

    anomaly_mse = np.array(anomaly_mse)

    # Görselleştirme
    plt.figure(figsize=(12, 6))
    plt.hist(normal_mse, bins=30, alpha=0.7, label='Normal', color='green')
    plt.hist(anomaly_mse, bins=30, alpha=0.7, label='Anomaly', color='red')
    plt.xlabel('MSE')
    plt.ylabel('Frequency')
    plt.legend()
    plt.title('MSE Distribution: Normal vs Anomaly')
    plt.show()

    # İstatistikler
    print(f"Normal MSE: {normal_mse.mean():.6f} ± {normal_mse.std():.6f}")
    print(f"Anomaly MSE: {anomaly_mse.mean():.6f} ± {anomaly_mse.std():.6f}")
    print(f"Separation ratio: {anomaly_mse.mean() / normal_mse.mean():.2f}x")

    return normal_mse, anomaly_mse

normal_scores, anomaly_scores = evaluate_model(model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Normal MSE: 0.011679 ± 0.001842
# Anomaly MSE: 0.015265 ± 0.005005
# Separation ratio: 1.31x
